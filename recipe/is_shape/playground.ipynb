# %%
import os
import pandas as pd

# %%
# data = pd.read_parquet("/mnt/tidal-alsh-hilab/usr/shenguobin/verl/recipe/is_shape/data/deepscaler/train.parquet")
data = pd.read_parquet("/mnt/tidal-alsh-hilab/usr/shenguobin/verl/recipe/is_shape/data/dapo_math/train.parquet")

# %%
data['prompt'][100]

# Please reason step by step, and put your final answer within \\boxed{}.

# Solve the following math problem step by step. The last line of your response should be of the form Answer: $Answer (without quotes) where $Answer is the answer to the problem.\n\n
# \n\nRemember to put your answer on its own line after "Answer:".
# Out:
# array([{'content': 'Three 12 cm $\\times$ 12 cm squares are each cut into two pieces $A$ and $B$, as shown in the first figure below, by joining the midpoints of two adjacent sides. These six pieces are then attached to a regular hexagon, as shown in the second figure, so as to fold into a polyhedron. What is the volume (in $\\text{cm}^3$) of this polyhedron? Please reason step by step, and put your final answer within \\boxed{}.', 'role': 'user'}],
#       dtype=object)

# %%
for x in data['extra_info']:
    if not x['has_images']:
        print(x)
# Out:
# {'answer_type': 'Numerical', 'difficulty': 'Competition', 'has_images': False, 'has_solution': True, 'index': 0, 'is_multiple_answer': False, 'language': 'English', 'modality': 'Text-only', 'original_id': 1606, 'question_type': 'Open-ended', 'split': 'test', 'subfield': 'Combinatorics', 'subject': 'Math', 'unit': None}
# {'answer_type': 'Expression', 'difficulty': 'Competition', 'has_images': False, 'has_solution': True, 'index': 1, 'is_multiple_answer': False, 'language': 'English', 'modality': 'Text-only', 'original_id': 1610, 'question_type': 'Open-ended', 'split': 'test', 'subfield': 'Algebra', 'subject': 'Math', 'unit': None}
# {'answer_type': 'Numerical', 'difficulty': 'Competition', 'has_images': False, 'has_solution': True, 'index': 2, 'is_multiple_answer': False, 'language': 'English', 'modality': 'Text-only', 'original_id': 1612, 'question_type': 'Open-ended', 'split': 'test', 'subfield': 'Number Theory', 'subject': 'Math', 'unit': None}
# ...
